# %%
import pandas as pd

# %%
works = pd.read_csv("./works.csv")

# %%
# Распределение по зарплате с высшим образованием
men_salary = works.query("gender == 'Мужской' and educationType == 'Высшее'").hist(bins=80, alpha=0.7)
works.query("gender == 'Женский' and educationType == 'Высшее'").hist(bins=80, alpha=0.7)
# Out:
# array([[<AxesSubplot:title={'center':'salary'}>]], dtype=object)

# %%
# Распределение по зарплате с незаконченным высшим образованием
works.query("gender == 'Мужской' and educationType == 'Незаконченное высшее'").hist(bins=80, alpha=0.7)
works.query("gender == 'Женский' and educationType == 'Незаконченное высшее'").hist(bins=80, alpha=0.7)
# Out:
# array([[<AxesSubplot:title={'center':'salary'}>]], dtype=object)

# %%
# Распределение по зарплате со средним профессиональным образованием
works.query("gender == 'Мужской' and educationType == 'Среднее профессиональное'").hist(bins=80, alpha=0.7)
works.query("gender == 'Женский' and educationType == 'Среднее профессиональное'").hist(bins=80, alpha=0.7)
# Out:
# array([[<AxesSubplot:title={'center':'salary'}>]], dtype=object)

# %%
# Распределение по зарплате со средним образованием
works.query("gender == 'Мужской' and educationType == 'Среднее'").hist(bins=80, alpha=0.7)
works.query("gender == 'Женский' and educationType == 'Среднее'").hist(bins=80, alpha=0.7)
# Out:
# array([[<AxesSubplot:title={'center':'salary'}>]], dtype=object)
